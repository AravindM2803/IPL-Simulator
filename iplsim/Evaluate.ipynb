# %%
#importing libraries
import pandas as pd
import numpy as np
import tensorflow as tf
import random
import functools
import math
import livelossplot
import pickle
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import pickle
from Utils.helper import *
from Utils.sample_squads import *

# %% [markdown]
# ## Innings 1

# %%
model_inn_1 = tf.keras.models.load_model('Models\Inn1-NewSimpleRNN-ep20to50\cp-0030.h5')

# %%
with open("Data\\Players", "rb") as fp:
    players_lis = pickle.load(fp)
players_lis
with open("Data\\BS_Cols.pkl", "rb") as fp:
    bs_cols_lis = pickle.load(fp)
players_lis
# Out:
# ['A Ashish Reddy',
#  'A Chandila',
#  'A Chopra',
#  'A Choudhary',
#  'A Flintoff',
#  'A Kumble',
#  'A Mishra',
#  'A Mithun',
#  'A Mukund',
#  'A Nehra',
#  'A Nel',
#  'A Singh',
#  'A Symonds',
#  'A Uniyal',
#  'A Zampa',
#  'AA Bilakhia',
#  'AA Chavan',
#  'AA Jhunjhunwala',
#  'AA Kazi',
#  'AA Noffke',
#  'AB Agarkar',
#  'AB Barath',
#  'AB Dinda',
#  'AB McDonald',
#  'AB de Villiers',
#  'AC Blizzard',
#  'AC Gilchrist',
#  'AC Thomas',
#  'AC Voges',
#  'AD Mascarenhas',
#  'AD Mathews',
#  'AD Nath',
#  'AD Russell',
#  'AF Milne',
#  'AG Murtaza',
#  'AG Paunikar',
#  'AJ Finch',
#  'AJ Tye',
#  'AL Menaria',
#  'AM Nayar',
#  'AM Rahane',
#  'AM Salvi',
#  'AN Ahmed',
#  'AN Ghosh',
#  'AP Dole',
#  'AP Majumdar',
#  'AP Tare',
#  'AR Bawne',
#  'AR Patel',
#  'AS Rajpoot',
#  'AS Raut',
#  'AS Yadav',
#  'AT Rayudu',
#  'AUK Pathan',
#  'Abdur Razzak',
#  'Anand Rajan',
#  'Anirudh Singh',
#  'Ankit Sharma',
#  'Ankit Soni',
#  'Anureet Singh',
#  'Avesh Khan',
# ...

# %%
bs_cols_lis
# Out:
# ['Balls',
#  'Batting_Team_Chennai Super Kings',
#  'Batting_Team_Deccan Chargers',
#  'Batting_Team_Delhi Daredevils',
#  'Batting_Team_Gujarat Lions',
#  'Batting_Team_Kings XI Punjab',
#  'Batting_Team_Kochi Tuskers Kerala',
#  'Batting_Team_Kolkata Knight Riders',
#  'Batting_Team_Mumbai Indians',
#  'Batting_Team_Pune Warriors',
#  'Batting_Team_Rajasthan Royals',
#  'Batting_Team_Rising Pune Supergiant',
#  'Batting_Team_Royal Challengers Bangalore',
#  'Batting_Team_Sunrisers Hyderabad',
#  'Bowler_A Ashish Reddy',
#  'Bowler_A Chandila',
#  'Bowler_A Chopra',
#  'Bowler_A Choudhary',
#  'Bowler_A Flintoff',
#  'Bowler_A Kumble',
#  'Bowler_A Mishra',
#  'Bowler_A Mithun',
#  'Bowler_A Mukund',
#  'Bowler_A Nehra',
#  'Bowler_A Nel',
#  'Bowler_A Singh',
#  'Bowler_A Symonds',
#  'Bowler_A Uniyal',
#  'Bowler_A Zampa',
#  'Bowler_AA Bilakhia',
#  'Bowler_AA Chavan',
#  'Bowler_AA Jhunjhunwala',
#  'Bowler_AA Kazi',
#  'Bowler_AA Noffke',
#  'Bowler_AB Agarkar',
# ...
