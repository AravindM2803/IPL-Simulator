# %%
#importing libraries
import pandas as pd
import numpy as np
import tensorflow as tf
import random
import functools
import math
import pickle
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
from tqdm import tqdm
from Utils.helper import *
from Utils.sample_squads import *
# Out:
# WARNING:tensorflow:From c:\Users\aravi\miniconda3\envs\iplsim\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model_inn_1 = tf.keras.models.load_model('GitData/Inn1BestModel.h5')
model_inn_2 = tf.keras.models.load_model('GitData/Inn2BestModel.h5')
# Out:
# WARNING:tensorflow:From c:\Users\aravi\miniconda3\envs\iplsim\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Sample Squads. To change batting or bowling line up, please uncomment, change and run this before executing the next cells

# RCB_Pitch = "M Chinnaswamy Stadium"
# RCB_Batting = ["Royal Challengers Bangalore", "PA Patel",
#                "V Kohli", "AB de Villiers",
#                "M Ali", "S Hetmyer", "S Dube",
#                "C de Grandhomme", "N Saini", "YS Chahal",
#                "UT Yadav", "Mohammed Siraj"]
# RCB_Bowling = ["Royal Challengers Bangalore", "Mohammed Siraj",
#                "UT Yadav", "Mohammed Siraj",
#                "UT Yadav", "C de Grandhomme", "N Saini",
#                "C de Grandhomme", "YS Chahal", "N Saini",
#                "YS Chahal", "N Saini", "YS Chahal",
#                "Mohammed Siraj", "YS Chahal",
#                "C de Grandhomme", "N Saini",
#                "C de Grandhomme", "UT Yadav",
#                "Mohammed Siraj", "UT Yadav"
#                ]
# RCB_Squad = [RCB_Batting, RCB_Bowling]

# SRH_Pitch = "Rajiv Gandhi International Stadium, Uppal"
# SRH_Batting = ["Sunrisers Hyderabad", "J Bairstow", "DA Warner",
#                "MK Pandey", "V Shankar", "YK Pathan", "DJ Hooda",
#                "Mohammad Nabi", "B Kumar",
#                "Rashid Khan", "S Kaul",
#                "Sandeep Sharma"]

# SRH_Bowling = ["Sunrisers Hyderabad", "B Kumar",
#                "Sandeep Sharma", "B Kumar",
#                "Sandeep Sharma", "Rashid Khan", "S Kaul",
#                "Rashid Khan", "Mohammad Nabi", "S Kaul",
#                "Mohammad Nabi", "S Kaul", "Mohammad Nabi",
#                "B Kumar", "Mohammad Nabi",
#                "Rashid Khan", "S Kaul",
#                "Rashid Khan", "Sandeep Sharma",
#                "B Kumar", "Sandeep Sharma"]

# SRH_Squad = [SRH_Batting, SRH_Bowling]

# DC_Pitch = "Feroz Shah Kotla"

# DC_Batting = ["Delhi Capitals", "P Shaw", "S Dhawan", "SS Iyer",
#               "RR Pant", "CA Ingram",
#               "S Rutherford", "AR Patel", "A Mishra",
#               "K Rabada", "I Sharma", "S Lamichhane"]
# DC_Bowling = ["Delhi Capitals", "I Sharma",
#               "K Rabada", "I Sharma",
#               "K Rabada", "AR Patel", "A Mishra",
#               "AR Patel", "S Lamichhane", "A Mishra",
#               "S Lamichhane", "A Mishra", "S Lamichhane",
#               "I Sharma", "S Lamichhane",
#               "AR Patel", "A Mishra",
#               "AR Patel", "K Rabada",
#               "I Sharma", "K Rabada"]
# DC_Squad = [DC_Batting, DC_Bowling]

# MI_Pitch = "Wankhede Stadium"
# MI_Batting = ["Mumbai Indians", "Q de Kock", "RG Sharma", "SA Yadav",
#               "Ishan Kishan", "HH Pandya",
#               "KA Pollard", "KH Pandya", "RD Chahar",
#               "J Behrendorff", "JJ Bumrah", "SL Malinga"
#               ]
# MI_Bowling = ["Mumbai Indians", "J Behrendorff", "SL Malinga",
#               "J Behrendorff", "SL Malinga", "J Behrendorff",
#               "JJ Bumrah", "RD Chahar",
#               "JJ Bumrah", "RD Chahar", "KH Pandya",
#               "RD Chahar", "KH Pandya", "KH Pandya",
#               "KH Pandya", "RD Chahar",
#               "JJ Bumrah", "SL Malinga", "J Behrendorff",
#               "JJ Bumrah", "SL Malinga"]
# MI_Squad = [MI_Batting, MI_Bowling]

# KXIP_Pitch = "Holkar Cricket Stadium"
# KXIP_Batting = ["Kings XI Punjab", "KL Rahul", "CH Gayle",
#                 "MA Agarwal", "DA Miller", "N Pooran",
#                 "Mandeep Singh",
#                 "R Ashwin", "H Viljoen", "M Ashwin",
#                 "Mohammed Shami", "AS Rajpoot"
#                 ]
# KXIP_Bowling = ["Kings XI Punjab", "AS Rajpoot", "Mohammed Shami",
#                 "AS Rajpoot", "Mohammed Shami", "AS Rajpoot",
#                 "H Viljoen", "M Ashwin",
#                 "H Viljoen", "M Ashwin", "R Ashwin",
#                 "M Ashwin", "R Ashwin", "R Ashwin",
#                 "R Ashwin", "M Ashwin",
#                 "H Viljoen", "Mohammed Shami", "AS Rajpoot",
#                 "H Viljoen", "Mohammed Shami"]
# KXIP_Squad = [KXIP_Batting, KXIP_Bowling]

# CSK_Pitch = "MA Chidambaram Stadium, Chepauk"
# CSK_Batting = ["Chennai Super Kings", "SR Watson", "F du Plessis",
#                "SK Raina", "AT Rayudu", "KM Jadhav",
#                "MS Dhoni", "RA Jadeja",
#                "DJ Bravo", "SN Thakur",
#                "DL Chahar", "Imran Tahir"]
# CSK_Bowling = ["Chennai Super Kings", "DL Chahar",
#                "SN Thakur", "DL Chahar",
#                "SN Thakur", "DL Chahar",
#                "SN Thakur", "RA Jadeja",
#                "Imran Tahir", "RA Jadeja",
#                "Imran Tahir", "RA Jadeja",
#                "Imran Tahir", "RA Jadeja",
#                "DJ Bravo", "Imran Tahir",
#                "DJ Bravo", "SN Thakur",
#                "DJ Bravo", "DL Chahar", "DJ Bravo"]
# CSK_Squad = [CSK_Batting, CSK_Bowling]

# RR_Batting = ["Rajasthan Royals", "AM Rahane",
#               "JC Buttler", "SV Samson", "SPD Smith",
#               "RA Tripathi", "BA Stokes",
#               "R Parag", "J Archer", "S Gopal",
#               "DS Kulkarni", "JD Unadkat"
#               ]

# RR_Pitch = "Sawai Mansingh Stadium"
# RR_Bowling = ["Rajasthan Royals", "JD Unadkat",
#               "DS Kulkarni", "JD Unadkat",
#               "DS Kulkarni", "JD Unadkat",
#               "DS Kulkarni", "R Parag",
#               "S Gopal", "R Parag",
#               "S Gopal", "R Parag",
#               "S Gopal", "R Parag",
#               "J Archer", "S Gopal",
#               "J Archer", "DS Kulkarni",
#               "J Archer", "JD Unadkat", "J Archer"]
# RR_Squad = [RR_Batting, RR_Bowling]

# KKR_Pitch = "Eden Gardens"
# KKR_Batting = ["Kolkata Knight Riders", "S Gill",
#                "CA Lynn", "RV Uthappa", "N Rana",
#                "AD Russell", "KD Karthik",
#                "SP Narine", "PP Chawla", "Kuldeep Yadav",
#                "L Ferguson", "Prasidh Krishna"
#                ]
# KKR_Bowling = ["Kolkata Knight Riders", "Prasidh Krishna",
#                "L Ferguson", "Prasidh Krishna", "L Ferguson",
#                "Prasidh Krishna", "SP Narine", "Kuldeep Yadav",
#                "SP Narine", "Kuldeep Yadav", "PP Chawla",
#                "Kuldeep Yadav", "PP Chawla", "PP Chawla",
#                "PP Chawla", "Kuldeep Yadav",
#                "SP Narine", "L Ferguson", "Prasidh Krishna",
#                "SP Narine", "L Ferguson"]
# KKR_Squad = [KKR_Batting, KKR_Bowling]

# %%
inn1_df = pd.DataFrame(columns=BF_Cols)
inn1 = Innings(RCB_Squad[0], CSK_Squad[1], CSK_Squad[0][0], CSK_Pitch, 1, inn1_df)
target = inn1.simulate_inning(model_inn_1)
# with open("Evaluation/best_first_innings.pkl", "rb") as fp:
#     inn1 = pickle.load(fp)["inn1"]
target = inn1.Runs + 1
display_batting_table(inn1)
# Out:
# Royal Challengers Bangalore  :  116 / 7  in  20 . 0
# Extras: 5
#             Batsman Runs Fours Sixes Balls Faced Dismissal Type Dismissed By
# 0          PA Patel    8     1     0           9         Caught    DL Chahar
# 1           V Kohli   28     2     2          21            LBW    SN Thakur
# 2    AB de Villiers    0     0     0           3         Caught    DL Chahar
# 3             M Ali    6     1     0           6         Caught    RA Jadeja
# 4         S Hetmyer    0     0     0           3            LBW  Imran Tahir
# 5            S Dube    1     0     0           4         Caught    RA Jadeja
# 6   C de Grandhomme   15     2     0          12         Caught  Imran Tahir
# 7           N Saini   37     3     0          38        Not Out            -
# 8         YS Chahal   16     0     0          24        Not Out            -
# 9          UT Yadav    -     -     -           -              -            -
# ...

# %%
inn2_df = pd.DataFrame(columns=BS_Cols)
inn2 = Innings(CSK_Squad[0], RCB_Squad[1], CSK_Squad[0][0], RCB_Pitch, 2, inn2_df, target)
inn2.simulate_inning(model_inn_2)
display_batting_table(inn2)
# Out:
# Chennai Super Kings  :  117 / 6  in  17 . 0
# Extras: 8
#          Batsman Runs Fours Sixes Balls Faced Dismissal Type     Dismissed By
# 0      SR Watson   28     2     1          30         Caught          N Saini
# 1   F du Plessis   14     1     1           9         Caught  C de Grandhomme
# 2       SK Raina   13     1     1           8         Caught  C de Grandhomme
# 3      AT Rayudu    6     0     0          12            LBW          N Saini
# 4      KM Jadhav   14     1     0          15         Bowled  C de Grandhomme
# 5       MS Dhoni    7     1     0          10         Caught        YS Chahal
# 6      RA Jadeja   14     3     0           8        Not Out                -
# 7       DJ Bravo   13     2     0           9        Not Out                -
# 8      SN Thakur    -     -     -           -              -                -
# 9      DL Chahar    -     -     -           -              -                -
# ...
